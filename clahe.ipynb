# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.colab.patches import cv2_imshow
os.chdir('/content/drive/My Drive/retinopathy dataset/sample')

# %%
import cv2
import numpy

# %%
image = cv2.imread('10_left.jpeg')
image = cv2.resize(image,(600,600))
image_bw = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
#declaration of clahe
clahe = cv2.createCLAHE(clipLimit=16)
final_img = clahe.apply(image_bw)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7F4974810C88>

# %%
_, ordinary_img = cv2.threshold(image_bw, 155, 255, cv2.THRESH_BINARY) 
cv2_imshow(ordinary_img)

# %%
cv2_imshow(final_img)
cv2_imshow(ordinary_img)
cv2_imshow(image)
cv2_imshow(image_bw)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7F4974810B70>
# <PIL.Image.Image image mode=L size=600x600 at 0x7F4974810A90>
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F4974810BE0>
# <PIL.Image.Image image mode=L size=600x600 at 0x7F4974810A90>
